# %%
#Part A
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import Counter
from nltk.util import ngrams
import re

# Load data
data = pd.read_csv("/Users/inkarbaidaly/Downloads/train-2.csv")
data
# Out:
#                                                   review sentiment     id
# 0      I argued with myself whether to rent this or n...  negative  41449
# 1      This was one of the dullest movies I have seen...  negative  18376
# 2      I didn't know what to expect from 'Ned Kelly',...  positive  31081
# 3      All the funny things happening in this sitcom ...  negative   5696
# 4      We all know a movie never does complete justic...  negative   5714
# ...                                                  ...       ...    ...
# 39995  Some good movies keep you in front of the TV, ...  negative  13645
# 39996  I recently watched Caprica again and thought I...  positive  45044
# 39997  A stupid teen supposed comedy that revolves a ...  negative  19453
# 39998  When Carol (Vanessa Hidalgo) starts looking in...  negative  13181
# 39999  Being a 90's child, I truly enjoyed this show ...  positive  13151
#
# [40000 rows x 3 columns]

# %%
import nltk
print(nltk.data.path)
# Out:
# ['/Users/inkarbaidaly/nltk_data', '/Library/Frameworks/Python.framework/Versions/3.10/nltk_data', '/Library/Frameworks/Python.framework/Versions/3.10/share/nltk_data', '/Library/Frameworks/Python.framework/Versions/3.10/lib/nltk_data', '/usr/share/nltk_data', '/usr/local/share/nltk_data', '/usr/lib/nltk_data', '/usr/local/lib/nltk_data']

# %%
# Create two datasets based on the "sentiment" column's value
normal_tweets = data[data["sentiment"] == "positive"]
disaster_tweets = data[data["sentiment"] == "negative"]
# Optional: Print the first few rows of each dataset
print("\nFirst few rows of positive_dataset:")
normal_tweets
# Out:
# First few rows of positive_dataset:
#                                                   review sentiment     id
# 2      I didn't know what to expect from 'Ned Kelly',...  positive  31081
# 5      i read the book before i saw the movie i knew ...  positive  46036
# 6      This has to be the ultimate chick flick ever. ...  positive  23583
# 7      A light-hearted comedy, Nothing shows us a wor...  positive  32635
# 8      Hadnt heard a lot about this movie, except it ...  positive   6022
# ...                                                  ...       ...    ...
# 39991  In what appears an attempt to mix drama and co...  positive  31525
# 39993  This is an excellent film!Tom Hanks and Paul N...  positive  47203
# 39994  I too was quite astonished to see how few peop...  positive   5522
# 39996  I recently watched Caprica again and thought I...  positive  45044
# 39999  Being a 90's child, I truly enjoyed this show ...  positive  13151
#
# [19938 rows x 3 columns]

# %%
print("\nFirst few rows of negative_dataset:")
disaster_tweets
# Out:
# First few rows of negative_dataset:
#                                                   review sentiment     id
# 0      I argued with myself whether to rent this or n...  negative  41449
# 1      This was one of the dullest movies I have seen...  negative  18376
# 3      All the funny things happening in this sitcom ...  negative   5696
# 4      We all know a movie never does complete justic...  negative   5714
# 9      The film, a Universal release of a Protelco-ML...  negative  18363
# ...                                                  ...       ...    ...
# 39989  I can say without a shadow of a doubt that Goi...  negative  27611
# 39992  Sarah Silverman is really the "flavor of the m...  negative  34468
# 39995  Some good movies keep you in front of the TV, ...  negative  13645
# 39997  A stupid teen supposed comedy that revolves a ...  negative  19453
# 39998  When Carol (Vanessa Hidalgo) starts looking in...  negative  13181
#
# [20062 rows x 3 columns]

# %%
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    text = re.sub(r'http\S+', '', text)  
    text = re.sub(r'@[^\s]+', '', text)  
    text = re.sub(r'[^\w\s]', '', text)   
    tokens = word_tokenize(text.lower()) 
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]  
    return ' '.join(tokens)

disaster_tweets.loc[:, 'review'] = disaster_tweets['review'].apply(preprocess_text)
normal_tweets.loc[:, 'review'] = normal_tweets['review'].apply(preprocess_text)

print("Disaster Dataset after Lemmatization:")
disaster_tweets['review'].head()
# Out:
# Disaster Dataset after Lemmatization:
# 0    argued whether rent im always afraid renting s...
# 1    one dullest movie seen time im late 40 watched...
# 3    funny thing happening sitcom based main charac...
# 4    know movie never complete justice book excepti...
# 9    film universal release protelcomlc production ...
# Name: review, dtype: object

# %%
print("\nNormal Dataset after Lemmatization:")
normal_tweets['review'].head()
# Out:
# Normal Dataset after Lemmatization:
# 2    didnt know expect ned kelly absolutely loved d...
# 5    read book saw movie knew movie going good book...
# 6    ultimate chick flick ever taped tv year ago iv...
# 7    lighthearted comedy nothing show u world somet...
# 8    hadnt heard lot movie except national award os...
# Name: review, dtype: object

# %%
from collections import Counter

disaster_word_counts = Counter()
normal_word_counts = Counter()

for index, row in disaster_tweets.iterrows():
    tokens = row['review'].split() 
    disaster_word_counts.update(tokens) 

for index, row in normal_tweets.iterrows():
    tokens = row['review'].split()  
    normal_word_counts.update(tokens)  

print("Word Counts in Disaster Tweets:")
print(disaster_word_counts)

print("\nWord Counts in Normal Tweets:")
print(normal_word_counts)
# Out:
# Word Counts in Disaster Tweets:
# Counter({'br': 46636, 'movie': 44780, 'film': 33760, 'one': 20826, 'like': 17865, 'even': 12132, 'good': 11369, 'bad': 11328, 'time': 11317, 'character': 11141, 'would': 10886, 'get': 10574, 'make': 10100, 'really': 9752, 'see': 8847, 'scene': 8833, 'story': 8423, 'dont': 8196, 'much': 7974, 'people': 7482, 'thing': 7459, 'could': 7260, 'made': 6770, 'plot': 6561, 'first': 6548, 'way': 6431, 'well': 6292, 'acting': 6230, 'think': 6078, 'go': 5973, 'know': 5943, 'show': 5939, 'look': 5927, 'also': 5739, 'watch': 5654, 'say': 5619, 'actor': 5559, 'never': 5294, 'better': 5208, 'seen': 5183, 'end': 5096, 'ever': 5078, 'two': 4865, 'little': 4759, 'many': 4716, 'nothing': 4590, 'im': 4528, 'something': 4497, 'guy': 4464, 'didnt': 4444, 'come': 4382, 'take': 4313, 'want': 4283, 'watching': 4212, 'life': 4194, 'doesnt': 4134, 'great': 4116, 'director': 4045, 'actually': 4043, 'minute': 3980, 'year': 3960, 'worst': 3846, 'give': 3791, 'part': 3764, 'man': 3763, 'work': 3708, 'lot': 3696, 'back': 3651, 'going': 3624, 'cant': 3616, 'find': 3576, 'another': 3545, 'woman': 3539, 'love': 3530, 'thats': 3515, 'still': 3514, 'funny': 3493, 'pretty': 3383, 'script': 3367, 'point': 3357, 'real': 3355, 'best': 3252, 'every': 3252, 'got': 3237, 'girl': 3186, 'least': 3176, 'seems': 3173, 'though': 3159, 'horror': 3159, 'old': 3158, 'fact': 3103, 'enough': 3097, 'isnt': 3018, 'around': 3007, 'u': 2999, 'thought': 2991, 'original': 2919, 'whole': 2902, 'play': 2889, 'anything': 2872, 'line': 2865, 'try': 2852, 'ive': 2814, 'reason': 2804, 'however': 2762, 'effect': 2698, 'feel': 2681, 'new': 2677, 'big': 2656, 'shot': 2637, 'action': 2621, 'cast': 2605, 'idea': 2602, 'might': 2591, 'far': 2589, 'long': 2576, 'right': 2570, 'kind': 2564, 'interesting': 2558, 'without': 2539, 'role': 2527, 'quite': 2516, 'start': 2516, 'day': 2510, 'star': 2505, 'almost': 2487, 'let': 2474, 'comedy': 2466, 'kid': 2436, 'fan': 2423, 'money': 2417, 'must': 2404, 'performance': 2388, 'book': 2374, 'friend': 2362, 'bit': 2358, 'poor': 2355, 'set': 2347, 'someone': 2342, 'trying': 2323, 'awful': 2316, 'put': 2308, 'done': 2298, '2': 2295, 'saw': 2295, 'wasnt': 2292, 'boring': 2285, 'maybe': 2285, 'probably': 2282, 'stupid': 2264, 'believe': 2264, 'mean': 2262, 'terrible': 2260, 'instead': 2256, 'rather': 2249, 'making': 2238, 'away': 2232, 'anyone': 2224, 'may': 2214, 'last': 2176, 'sure': 2172, 'need': 2153, 'since': 2137, 'looking': 2128, 'waste': 2121, 'world': 2104, 'problem': 2097, 'tv': 2072, 'hour': 2047, 'tell': 2045, 'audience': 2030, 'place': 2025, 'music': 2018, 'hard': 2000, 'young': 1994, 'found': 1990, 'main': 1986, 'turn': 1984, 'completely': 1929, 'sense': 1928, 'everything': 1924, 'worse': 1897, 'moment': 1862, 'said': 1858, 'special': 1856, 'always': 1853, 'series': 1853, 'yet': 1852, 'ending': 1846, 'watched': 1835, 'half': 1831, 'laugh': 1823, 'else': 1814, 'left': 1807, 'family': 1806, 'seem': 1805, 'name': 1804, 'supposed': 1798, 'course': 1789, 'youre': 1778, 'sound': 1769, 'either': 1765, '10': 1755, 'second': 1752, 'screen': 1746, 'worth': 1730, 'simply': 1728, 'wrong': 1727, 'american': 1725, 'attempt': 1719, 'horrible': 1712, 'read': 1703, 'kill': 1701, 'camera': 1694, 'night': 1693, 'couldnt': 1688, 'oh': 1675, 'le': 1671, 'piece': 1667, 'three': 1666, 'rest': 1662, 'child': 1657, 'version': 1653, 'played': 1651, 'joke': 1649, 'dialogue': 1643, 'budget': 1630, 'fun': 1616, 'black': 1615, 'house': 1613, 'lead': 1613, 'keep': 1605, 'dead': 1605, 'although': 1600, 'production': 1590, 'help': 1578, 'head': 1574, 'video': 1570, 'seeing': 1556, 'everyone': 1553, 'sex': 1551, 'couple': 1537, 'death': 1537, 'used': 1531, 'given': 1529, 'high': 1527, 'flick': 1507, 'dvd': 1506, 'killer': 1505, 'lack': 1505, 'boy': 1500, 'sort': 1498, 'together': 1497, 'word': 1494, 'review': 1483, 'care': 1482, 'mind': 1475, 'getting': 1470, 'face': 1463, 'use': 1461, '1': 1444, 'especially': 1438, '3': 1435, 'unfortunately': 1423, 'next': 1423, 'short': 1422, 'wife': ...
#
# Word Counts in Normal Tweets:
# Counter({'br': 43913, 'film': 38171, 'movie': 34550, 'one': 21904, 'like': 14116, 'time': 12166, 'good': 11550, 'character': 10960, 'story': 10858, 'great': 10151, 'see': 10116, 'well': 9035, 'get': 8836, 'make': 8738, 'really': 8573, 'also': 8539, 'would': 8279, 'scene': 7731, 'even': 7466, 'show': 7435, 'life': 7300, 'much': 7211, 'first': 7165, 'love': 7058, 'people': 6935, 'way': 6802, 'best': 6659, 'many': 6077, 'think': 6052, 'year': 5762, 'made': 5637, 'thing': 5535, 'two': 5534, 'go': 5476, 'know': 5298, 'dont': 5288, 'watch': 5288, 'seen': 5245, 'little': 5134, 'still': 5048, 'never': 5034, 'man': 5013, 'could': 4879, 'actor': 4813, 'end': 4791, 'work': 4674, 'say': 4673, 'performance': 4629, 'take': 4620, 'come': 4394, 'find': 4391, 'look': 4275, 'u': 4252, 'ever': 4140, 'part': 4122, 'play': 4036, 'lot': 4014, 'give': 3976, 'role': 3888, 'real': 3875, 'back': 3854, 'plot': 3813, 'acting': 3692, 'better': 3648, 'world': 3641, 'new': 3630, 'though': 3595, 'want': 3593, 'young': 3495, 'director': 3417, 'woman': 3384, 'something': 3356, 'quite': 3319, 'cast': 3254, 'always': 3225, 'another': 3213, 'day': 3184, 'every': 3174, 'old': 3169, 'family': 3159, 'comedy': 3125, 'funny': 3115, 'may': 3073, 'series': 3042, 'feel': 3035, 'music': 3011, 'doesnt': 2992, 'im': 2989, 'watching': 2947, 'going': 2882, 'bit': 2876, 'bad': 2869, 'girl': 2808, 'friend': 2785, 'fan': 2752, 'guy': 2740, 'saw': 2739, 'thought': 2723, 'right': 2719, 'actually': 2718, 'didnt': 2705, 'however': 2704, 'big': 2686, 'star': 2683, 'fact': 2677, 'action': 2662, 'excellent': 2620, 'must': 2586, 'got': 2581, 'without': 2571, 'around': 2568, 'long': 2542, 'point': 2526, 'fun': 2515, 'ive': 2491, 'set': 2484, 'seems': 2472, 'war': 2454, 'almost': 2415, 'pretty': 2411, 'played': 2409, 'cant': 2402, 'last': 2401, 'episode': 2395, 'especially': 2393, 'horror': 2387, 'beautiful': 2386, 'yet': 2370, 'moment': 2366, 'thats': 2358, 'since': 2354, 'although': 2339, 'done': 2321, 'different': 2309, 'job': 2304, 'dvd': 2297, 'enough': 2264, 'place': 2238, 'interesting': 2232, 'kid': 2230, 'line': 2210, 'true': 2205, 'child': 2175, 'tv': 2174, 'american': 2154, 'found': 2124, 'probably': 2119, 'course': 2113, 'wonderful': 2109, 'put': 2096, 'isnt': 2094, 'kind': 2088, 'original': 2082, 'turn': 2039, 'far': 2039, 'classic': 2038, 'keep': 2018, 'rather': 2001, 'shot': 1999, 'john': 1998, 'whole': 1986, 'start': 1984, 'nothing': 1982, 'away': 1980, 'sure': 1980, 'worth': 1973, 'tell': 1971, 'later': 1955, 'need': 1951, 'anyone': 1945, 'try': 1931, 'book': 1928, 'audience': 1926, 'might': 1924, 'boy': 1909, 'together': 1904, 'perfect': 1899, 'help': 1893, 'screen': 1879, 'father': 1870, 'three': 1869, 'wife': 1868, 'ending': 1867, 'everything': 1859, 'version': 1853, 'let': 1790, 'night': 1786, 'effect': 1781, 'loved': 1779, 'short': 1775, 'human': 1764, 'everyone': 1763, 'hard': 1753, 'song': 1748, 'seeing': 1747, 'making': 1746, 'watched': 1741, 'death': 1735, 'enjoy': 1725, 'main': 1694, 'believe': 1689, 'nice': 1686, '10': 1684, 'anything': 1675, 'lead': 1675, 'recommend': 1673, 'favorite': 1673, 'viewer': 1672, 'least': 1663, 'mind': 1658, 'home': 1651, 'reason': 1640, 'black': 1636, 'minute': 1633, 'second': 1632, 'eye': 1632, 'picture': 1631, 'men': 1631, 'definitely': 1620, 'sense': 1618, 'along': 1615, 'truly': 1595, 'le': 1586, 'seem': 1562, 'looking': 1558, 'amazing': 1541, 'trying': 1541, 'hollywood': 1531, 'said': 1530, 'script': 1525, 'others': 1524, 'special': 1515, 'high': 1514, 'house': 1504, 'mother': 1499, 'remember': 1496, 'idea': 1479, 'often': 1468, 'mean': 1465, 'left': 1464, 'today': 1461, 'game': 1460, 'used': 1454, 'style': 1451, 'problem': 1450, 'mr': 1443, 'face': 1438, 'brilliant': 1434, 'top': 1430, 'maybe': 1423, 'early': 1420, 'liked': 1416, 'hope': 1411, 'drama': 1411, 'full': 1406, 'feeling': 1404, 'read': 1402, 'small': 1402, 'become': 1391, 'sound': 1382, 'laugh': 1381, 'production': 1377, 'heart': 1365, 'enjoyed': 1359, 'brother': 13 ...

# %%
top_disaster_words = disaster_word_counts.most_common(20)
top_normal_words = normal_word_counts.most_common(20)

print("Top 20 words in disaster tweets:")
print(top_disaster_words)
print("\nTop 20 words in normal tweets:")
print(top_normal_words)
# Out:
# Top 20 words in disaster tweets:
# [('br', 46636), ('movie', 44780), ('film', 33760), ('one', 20826), ('like', 17865), ('even', 12132), ('good', 11369), ('bad', 11328), ('time', 11317), ('character', 11141), ('would', 10886), ('get', 10574), ('make', 10100), ('really', 9752), ('see', 8847), ('scene', 8833), ('story', 8423), ('dont', 8196), ('much', 7974), ('people', 7482)]
#
# Top 20 words in normal tweets:
# [('br', 43913), ('film', 38171), ('movie', 34550), ('one', 21904), ('like', 14116), ('time', 12166), ('good', 11550), ('character', 10960), ('story', 10858), ('great', 10151), ('see', 10116), ('well', 9035), ('get', 8836), ('make', 8738), ('really', 8573), ('also', 8539), ('would', 8279), ('scene', 7731), ('even', 7466), ('show', 7435)]

# %%
def preprocess_and_extract_ngrams(text, n):
    text = re.sub(r'http\S+', '', text) 
    text = re.sub(r'@[^\s]+', '', text) 
    text = re.sub(r'[^\w\s]', '', text)   
    tokens = word_tokenize(text.lower())  
    tokens = [word for word in tokens if word not in stop_words] 
    n_grams = list(ngrams(tokens, n)) 
    return n_grams

disaster_bigrams = disaster_tweets['review'].apply(lambda x: preprocess_and_extract_ngrams(x, 2))
disaster_trigrams = disaster_tweets['review'].apply(lambda x: preprocess_and_extract_ngrams(x, 3))

normal_bigrams = normal_tweets['review'].apply(lambda x: preprocess_and_extract_ngrams(x, 2))
normal_trigrams = normal_tweets['review'].apply(lambda x: preprocess_and_extract_ngrams(x, 3))

disaster_flat_bigrams = [bigram for sublist in disaster_bigrams for bigram in sublist]
disaster_flat_trigrams = [trigram for sublist in disaster_trigrams for trigram in sublist]

normal_flat_bigrams = [bigram for sublist in normal_bigrams for bigram in sublist]
normal_flat_trigrams = [trigram for sublist in normal_trigrams for trigram in sublist]


disaster_bigram_counts = Counter(disaster_flat_bigrams)
disaster_trigram_counts = Counter(disaster_flat_trigrams)

normal_bigram_counts = Counter(normal_flat_bigrams)
normal_trigram_counts = Counter(normal_flat_trigrams)


top_disaster_bigrams = disaster_bigram_counts.most_common(20)
top_disaster_trigrams = disaster_trigram_counts.most_common(20)

top_normal_bigrams = normal_bigram_counts.most_common(20)
top_normal_trigrams = normal_trigram_counts.most_common(20)

print("Top 20 bigrams in disaster tweets:")
print(top_disaster_bigrams)
print("\nTop 20 trigrams in disaster tweets:")
print(top_disaster_trigrams)

print("\nTop 20 bigrams in normal tweets:")
print(top_normal_bigrams)
print("\nTop 20 trigrams in normal tweets:")
print(top_normal_trigrams)
# Out:
# Top 20 bigrams in disaster tweets:
# [(('br', 'br'), 5207), (('look', 'like'), 1749), (('ever', 'seen'), 1314), (('special', 'effect'), 1159), (('br', 'movie'), 1127), (('waste', 'time'), 1082), (('dont', 'know'), 936), (('bad', 'movie'), 906), (('br', 'film'), 890), (('worst', 'movie'), 880), (('itbr', 'br'), 874), (('main', 'character'), 869), (('ive', 'seen'), 868), (('movie', 'like'), 824), (('movie', 'ever'), 817), (('moviebr', 'br'), 813), (('horror', 'movie'), 790), (('much', 'better'), 766), (('one', 'worst'), 750), (('even', 'though'), 720)]
#
# Top 20 trigrams in disaster tweets:
# [(('ive', 'ever', 'seen'), 514), (('worst', 'movie', 'ever'), 440), (('movie', 'ever', 'seen'), 293), (('dont', 'waste', 'time'), 274), (('one', 'worst', 'movie'), 255), (('movie', 'ive', 'ever'), 229), (('worst', 'film', 'ever'), 218), (('movie', 'ever', 'made'), 189), (('worst', 'movie', 'ive'), 186), (('film', 'ever', 'seen'), 160), (('waste', 'time', 'money'), 146), (('one', 'worst', 'film'), 141), (('dont', 'get', 'wrong'), 140), (('movie', 'br', 'br'), 140), (('br', 'br', 'movie'), 139), (('movie', 'ive', 'seen'), 129), (('film', 'ever', 'made'), 122), (('film', 'ive', 'ever'), 103), (('br', 'br', 'film'), 96), (('bad', 'acting', 'bad'), 95)]
#
# Top 20 bigrams in normal tweets:
# [(('br', 'br'), 5073), (('one', 'best'), 1301), (('br', 'film'), 1187), (('br', 'movie'), 897), (('ive', 'seen'), 861), (('even', 'though'), 854), (('first', 'time'), 727), (('ever', 'seen'), 713), (('itbr', 'br'), 710), (('dont', 'know'), 693), (('new', 'york'), 668), (('main', 'character'), 663), (('br', 'one'), 661), (('year', 'old'), 616), (('special', 'effect'), 613), (('see', 'movie'), 605), (('filmbr', 'br'), 605), (('look', 'like'), 594), (('year', 'ago'), 581), (('good', 'movie'), 579)]
#
# Top 20 trigrams in normal tweets:
# [(('ive', 'ever', 'seen'), 278), (('new', 'york', 'city'), 145), (('film', 'ive', 'seen'), 129), (('br', 'br', 'film'), 128), (('world', 'war', 'ii'), 126), (('one', 'best', 'movie'), 116), (('film', 'ever', 'made'), 108), (('one', 'best', 'film'), 106), (('movie', 'ive', 'seen'), 103), (('based', 'true', 'story'), 95), (('movie', 'br', 'br'), 94), (('movie', 'ever', 'seen'), 93), (('first', 'time', 'saw'), 92), (('br', 'br', 'movie'), 90), (('movie', 'ever', 'made'), 87), (('film', 'br', 'br'), 86), (('br', 'br', 'one'), 85), (('first', 'saw', 'movie'), 80), (('br', 'one', 'thing'), 79), (('best', 'movie', 'ever'), 77)]

# %%
###Part B

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'@[^\s]+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word.lower() not in stop_words]
    return ' '.join(tokens)

disaster_tweets.loc[:, 'review'] = disaster_tweets['review'].apply(preprocess_text)
normal_tweets.loc[:, 'review'] = normal_tweets['review'].apply(preprocess_text)

print("Disaster Dataset after Preprocessing:")
print(disaster_tweets['review'].head())

print("\nNormal Dataset after Preprocessing:")
print(normal_tweets['review'].head())
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:997)>
# Disaster Dataset after Preprocessing:
# 0    argued whether rent im always afraid renting s...
# 1    one dullest movie seen time im late 40 watched...
# 3    funny thing happening sitcom based main charac...
# 4    know movie never complete justice book excepti...
# 9    film universal release protelcomlc production ...
# Name: review, dtype: object
#
# Normal Dataset after Preprocessing:
# 2    didnt know expect ned kelly absolutely loved d...
# 5    read book saw movie knew movie going good book...
# 6    ultimate chick flick ever taped tv year ago iv...
# 7    lighthearted comedy nothing show u world somet...
# 8    hadnt heard lot movie except national award os...
# Name: review, dtype: object

# %%
#Part C

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, recall_score


X_train, X_test, y_train, y_test = train_test_split(data['review'], data['sentiment'], test_size=0.2, random_state=42)

max_features_values = [100, 1000]

for max_features in max_features_values:
    vectorizer = CountVectorizer(max_features=max_features)
    
    X_train_vectorized = vectorizer.fit_transform(X_train)
    
    X_test_vectorized = vectorizer.transform(X_test)
    
    model = LogisticRegression(max_iter=1000)
    
    model.fit(X_train_vectorized, y_train)
    
    y_pred = model.predict(X_test_vectorized)
    
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    
    print(f"\nPerformance with max_features={max_features}:")
    print(f"Accuracy: {accuracy}")
    print(f"F1 Score: {f1}")
    print(f"Recall: {recall}")
# Out:
# Performance with max_features=100:
# Accuracy: 0.733625
# F1 Score: 0.7335920477969484
# Recall: 0.733625
#
# Performance with max_features=1000:
# Accuracy: 0.865
# F1 Score: 0.8650131632404323
# Recall: 0.865
